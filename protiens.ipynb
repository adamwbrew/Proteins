# %%
import pandas as pd

# %%
protiens = pd.read_excel("Adam_Proteomics.xlsx", sheet_name=0, header=1)
protiens_identifiers = pd.read_excel("Adam_Proteomics.xlsx", sheet_name=1, header=0)

# %%
protiens.head()
# Out:
#   Protein.Group                                    Protein.Ids Protein.Names  \
# 0        P68369                    P05214;P68369;P68373;Q9JJZ2   TBA1A_MOUSE
# 1        P68368  P05213;P68368;P68369;P68373;Q3UX10;A0A0A0MQA5   TBA4A_MOUSE
# 2        P11798                  P11798;F8WHB5;F8WIS9;P11798-2   KCC2A_MOUSE
# 3        Q9QWL7                                         Q9QWL7   K1C17_MOUSE
# 4        Q9ERD7                                  Q922F4;Q9ERD7    TBB3_MOUSE
#
#     Genes                          First.Protein.Description  Peptides  \
# 0  Tuba1a                             Tubulin alpha-1A chain       8.0
# 1  Tuba4a                             Tubulin alpha-4A chain      28.0
# 2  Camk2a  Calcium/calmodulin-dependent protein kinase ty...      31.0
# 3   Krt17                    Keratin, type I cytoskeletal 17      28.0
# 4   Tubb3                               Tubulin beta-3 chain      18.0
#
#   1135-MRL_12  3057-MLL-LP1_2  3057-MLL-LS1_1  3057-MLL-NUC_3  ...  \
# ...

# %%
protiens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5884 entries, 0 to 5883
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Protein.Group              5883 non-null   object
#  1   Protein.Ids                5883 non-null   object
#  2   Protein.Names              5883 non-null   object
#  3   Genes                      5883 non-null   object
#  4   First.Protein.Description  5883 non-null   object
#  5   Peptides                   5883 non-null   float64
#  6   1135-MRL_12                5884 non-null   object
#  7   3057-MLL-LP1_2             5883 non-null   float64
#  8   3057-MLL-LS1_1             5883 non-null   float64
#  9   3057-MLL-NUC_3             5883 non-null   float64
#  10  3057-MRL-LP1_10            5883 non-null   float64
#  11  3057-MRL-LS1_7             5883 non-null   float64
#  12  3058-FRL_5                 5884 non-null   object
# ...

# %%
protiens_identifiers = protiens_identifiers.rename(columns= {"Unnamed: 0": "Sample_Name"})
protiens_identifiers.head(20)
# Out:
#         Sample_Name          Virus  Biotin     Fraction
# 0       1135-MRL_12        TurboID      72  whole brain
# 1    3057-MLL-LP1_2  TDP43-TurboID     1.5          LP1
# 2    3057-MLL-LS1_1  TDP43-TurboID     1.5          LS1
# 3    3057-MLL-NUC_3  TDP43-TurboID     1.5      Nuclear
# 4   3057-MRL-LP1_10  TDP43-TurboID  saline          LP1
# 5    3057-MRL-LS1_7  TDP43-TurboID  saline          LS1
# 6        3058-FRL_5        TurboID     1.5  whole brain
# 7       3058-FRU_13        TurboID      72  whole brain
# 8    3058-FRU-LP1_9        TurboID      72          LP1
# 9    3058-FRU-LS1_6        TurboID      72          LS1
# 10      3058-MRU_15  TDP43-TurboID      72  whole brain
# 11       3062-MRL_4  TDP43-TurboID     1.5  whole brain
# 12      3062-MRU_14  TDP43-TurboID      72  whole brain
# 13  3062-MRU-LP1_11  TDP43-TurboID      72          LP1
# 14   3062-MRU-LS1_8  TDP43-TurboID      72          LS1

# %%
protiens.columns
# Out:
# Index(['Protein.Group', 'Protein.Ids', 'Protein.Names', 'Genes',
#        'First.Protein.Description', 'Peptides', '1135-MRL_12',
#        '3057-MLL-LP1_2', '3057-MLL-LS1_1', '3057-MLL-NUC_3', '3057-MRL-LP1_10',
#        '3057-MRL-LS1_7', '3058-FRL_5', '3058-FRU_13', '3058-FRU-LP1_9',
#        '3058-FRU-LS1_6', '3058-MRU_15', '3062-MRL_4', '3062-MRU_14',
#        '3062-MRU-LP1_11', '3062-MRU-LS1_8'],
#       dtype='object')

# %%
protiens = protiens[["Protein.Names", 'Protein.Group', 'Protein.Ids', 'Genes',
       'First.Protein.Description', 'Peptides', '1135-MRL_12',
       '3057-MLL-LP1_2', '3057-MLL-LS1_1', '3057-MLL-NUC_3', '3057-MRL-LP1_10',
       '3057-MRL-LS1_7', '3058-FRL_5', '3058-FRU_13', '3058-FRU-LP1_9',
       '3058-FRU-LS1_6', '3058-MRU_15', '3062-MRL_4', '3062-MRU_14',
       '3062-MRU-LP1_11', '3062-MRU-LS1_8']]

# %%
protiens.tail()
# Out:
#      Protein.Names Protein.Group                         Protein.Ids   Genes  \
# 5879   HDAC6_MOUSE        Q9Z2V5            Q9Z2V5;A0A1B0GX25;B1AUA8   Hdac6
# 5880   HDAC5_MOUSE        Q9Z2V6  Q9Z2V6;A2AWS5;B7ZDF5;B7ZDF7;Q3UJF1   Hdac5
# 5881   PSD10_MOUSE        Q9Z2X2                              Q9Z2X2  Psmd10
# 5882  S4R1W5_MOUSE        S4R1W5                       S4R1W5;Q3ULB0    Rbm6
# 5883           NaN           NaN                                 NaN     NaN
#
#                             First.Protein.Description  Peptides 1135-MRL_12  \
# 5879                            Histone deacetylase 6       2.0           0
# 5880                            Histone deacetylase 5      10.0           0
# 5881  26S proteasome non-ATPase regulatory subunit 10       2.0           0
# 5882                      RNA-binding motif protein 6      11.0           0
# 5883                                              NaN       NaN     TurboID
#
# ...

# %%
# drop repeated bottom row
protiens = protiens.drop([5883], axis = 0)

# %%
# check if protien names are unique to protien groups
protiens[["Protein.Names", "Protein.Group"]].sort_values(by = ["Protein.Names"], ascending=True)
# Out:
#                   Protein.Names    Protein.Group
# 817   1433B-2_MOUSE;1433B_MOUSE  Q9CQV8;Q9CQV8-2
# 320                 1433E_MOUSE           P62259
# 329                 1433F_MOUSE           P68510
# 131                 1433G_MOUSE           P61982
# 610                 1433S_MOUSE           O70456
# ...                         ...              ...
# 2646                 ZW10_MOUSE           O54692
# 2547                ZWINT_MOUSE           Q9CQU5
# 3696                ZY11B_MOUSE           Q3UFS0
# 5055                  ZYX_MOUSE           Q62523
# 3939  ZZEF1-2_MOUSE;ZZEF1_MOUSE  Q5SSH7;Q5SSH7-2
#
# [5883 rows x 2 columns]

# %%
protiens_identifiers.head(20)
# Out:
#         Sample_Name          Virus  Biotin     Fraction
# 0       1135-MRL_12        TurboID      72  whole brain
# 1    3057-MLL-LP1_2  TDP43-TurboID     1.5          LP1
# 2    3057-MLL-LS1_1  TDP43-TurboID     1.5          LS1
# 3    3057-MLL-NUC_3  TDP43-TurboID     1.5      Nuclear
# 4   3057-MRL-LP1_10  TDP43-TurboID  saline          LP1
# 5    3057-MRL-LS1_7  TDP43-TurboID  saline          LS1
# 6        3058-FRL_5        TurboID     1.5  whole brain
# 7       3058-FRU_13        TurboID      72  whole brain
# 8    3058-FRU-LP1_9        TurboID      72          LP1
# 9    3058-FRU-LS1_6        TurboID      72          LS1
# 10      3058-MRU_15  TDP43-TurboID      72  whole brain
# 11       3062-MRL_4  TDP43-TurboID     1.5  whole brain
# 12      3062-MRU_14  TDP43-TurboID      72  whole brain
# 13  3062-MRU-LP1_11  TDP43-TurboID      72          LP1
# 14   3062-MRU-LS1_8  TDP43-TurboID      72          LS1

# %%
protiens_identifiers["Sample_Name"].value_counts()
# Out:
# 3062-MRU-LP1_11    1
# 3058-FRL_5         1
# 3057-MLL-LP1_2     1
# 3062-MRU_14        1
# 3057-MRL-LP1_10    1
# 3058-FRU-LP1_9     1
# 3058-MRU_15        1
# 3062-MRU-LS1_8     1
# 3057-MLL-LS1_1     1
# 3058-FRU_13        1
# 3062-MRL_4         1
# 3057-MLL-NUC_3     1
# 3057-MRL-LS1_7     1
# 1135-MRL_12        1
# 3058-FRU-LS1_6     1
# Name: Sample_Name, dtype: int64

# %%
# check for null values
pd.DataFrame(protiens.isna().value_counts())
# Out:
#                                                                                                                                                                                                                                                                                                     0
# Protein.Names Protein.Group Protein.Ids Genes First.Protein.Description Peptides 1135-MRL_12 3057-MLL-LP1_2 3057-MLL-LS1_1 3057-MLL-NUC_3 3057-MRL-LP1_10 3057-MRL-LS1_7 3058-FRL_5 3058-FRU_13 3058-FRU-LP1_9 3058-FRU-LS1_6 3058-MRU_15 3062-MRL_4 3062-MRU_14 3062-MRU-LP1_11 3062-MRU-LS1_8
# False         False         False       False False                     False    False       False          False          False          False           False          False      False       False          False          False       False      False       False           False           5883

# %%
# check varchar lengths
for col in protiens.columns:
    if(isinstance(protiens[f"{col}"][0],int) or isinstance(protiens[f"{col}"][0],float)): 
        continue
    else:
        print(f"{col}")
        print(len(protiens[f"{col}"].max()))

print("------------------\n")
for col in protiens_identifiers.columns:
    if(isinstance(protiens_identifiers[f"{col}"][0],int) or isinstance(protiens_identifiers[f"{col}"][0],float)): 
        continue
    else:
        print(f"{col}")
        print(len(protiens_identifiers[f"{col}"].max()))
# Out:
# Protein.Names
# 25
# Protein.Group
# 6
# Protein.Ids
# 20
# Genes
# 6
# First.Protein.Description
# 51
# ------------------
#
# Sample_Name
# 11
# Virus
# 7
# Fraction
# 11

# %%
protiens["Peptides"] = protiens["Peptides"].astype(int)

# %% [markdown]
# ## Change columns to proper data types

# %%
protiens[[ '1135-MRL_12', '3057-MLL-LP1_2', '3057-MLL-LS1_1', '3057-MLL-NUC_3', '3057-MRL-LP1_10',
       '3057-MRL-LS1_7', '3058-FRL_5', '3058-FRU_13', '3058-FRU-LP1_9',
       '3058-FRU-LS1_6', '3058-MRU_15', '3062-MRL_4', '3062-MRU_14',
       '3062-MRU-LP1_11', '3062-MRU-LS1_8']].head()
# Out:
#   1135-MRL_12  3057-MLL-LP1_2  3057-MLL-LS1_1  3057-MLL-NUC_3  \
# 0    13013100     161783000.0     346231000.0       3521250.0
# 1     6616000     160863000.0     513050000.0       2729930.0
# 2     7995310     126170000.0      23194300.0        897933.0
# 3    83662500     119307000.0     106735000.0      86980600.0
# 4     4078410     117870000.0     493320000.0       2155010.0
#
#    3057-MRL-LP1_10  3057-MRL-LS1_7 3058-FRL_5 3058-FRU_13 3058-FRU-LP1_9  \
# 0      248236000.0       5575930.0   23416100    78595300       63324700
# 1      227471000.0       3409790.0   18851000    51698000       58741500
# 2      159519000.0        208834.0   22436500    43949600       99779900
# 3      167563000.0      29730700.0   68578500    32354000       23324800
# 4      143086000.0       3124130.0   17367900    44406300       37950900
#
#   3058-FRU-LS1_6  3058-MRU_15  3062-MRL_4  3062-MRU_14  3062-MRU-LP1_11  \
# 0        6786260   43049300.0  22756200.0  162660000.0     3.018330e+09
# ...

# %%
protiens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5883 entries, 0 to 5882
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Protein.Names              5883 non-null   object
#  1   Protein.Group              5883 non-null   object
#  2   Protein.Ids                5883 non-null   object
#  3   Genes                      5883 non-null   object
#  4   First.Protein.Description  5883 non-null   object
#  5   Peptides                   5883 non-null   int32
#  6   1135-MRL_12                5883 non-null   object
#  7   3057-MLL-LP1_2             5883 non-null   float64
#  8   3057-MLL-LS1_1             5883 non-null   float64
#  9   3057-MLL-NUC_3             5883 non-null   float64
#  10  3057-MRL-LP1_10            5883 non-null   float64
#  11  3057-MRL-LS1_7             5883 non-null   float64
#  12  3058-FRL_5                 5883 non-null   object
# ...

# %%
protiens["Protein.Names"] = protiens["Protein.Names"].astype(str)
protiens["Protein.Group"] = protiens["Protein.Group"].astype(str)
protiens["Protein.Ids"] = protiens["Protein.Ids"].astype(str)
protiens["Genes"] = protiens["Genes"].astype(str)
protiens["First.Protein.Description"] = protiens["First.Protein.Description"].astype(str)
protiens["Peptides"] = protiens["Peptides"].astype(int)

protiens = protiens.rename(columns= {"Protein.Names":"Protein_Names",
                                     "Protein.Group":"Protein_Group",
                                     "Protein.Ids":"Protein_Ids",
                                     "First.Protein.Description":"First_Protein_Description"})
                                     
protiens["1135-MRL_12"] = protiens["1135-MRL_12"].astype(float)

protiens["3057-MLL-LP1_2"] = protiens["3057-MLL-LP1_2"].astype(float)
protiens["3057-MLL-LS1_1"] = protiens["3057-MLL-LS1_1"].astype(float)
protiens["3057-MLL-NUC_3"] = protiens["3057-MLL-NUC_3"].astype(float)
protiens["3057-MRL-LP1_10"] = protiens["3057-MRL-LP1_10"].astype(float)
protiens["3057-MRL-LS1_7"] = protiens["3057-MRL-LS1_7"].astype(float)

protiens["3058-FRL_5"] = protiens["3058-FRL_5"].astype(float)
protiens["3058-FRU_13"] = protiens["3058-FRU_13"].astype(float)
protiens["3058-FRU-LP1_9"] = protiens["3058-FRU-LP1_9"].astype(float)
protiens["3058-FRU-LS1_6"] = protiens["3058-FRU-LS1_6"].astype(float)
protiens["3058-MRU_15"] = protiens["3058-MRU_15"].astype(float)

protiens["3062-MRL_4"] = protiens["3062-MRL_4"].astype(float)
protiens["3062-MRU_14"] = protiens["3062-MRU_14"].astype(float)
protiens["3062-MRU-LP1_11"] = protiens["3062-MRU-LP1_11"].astype(float)
protiens["3062-MRU-LS1_8"] = protiens["3062-MRU-LS1_8"].astype(float)

protiens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5883 entries, 0 to 5882
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Protein_Names              5883 non-null   object
#  1   Protein_Group              5883 non-null   object
#  2   Protein_Ids                5883 non-null   object
#  3   Genes                      5883 non-null   object
#  4   First_Protein_Description  5883 non-null   object
#  5   Peptides                   5883 non-null   int32
#  6   1135-MRL_12                5883 non-null   float64
#  7   3057-MLL-LP1_2             5883 non-null   float64
#  8   3057-MLL-LS1_1             5883 non-null   float64
#  9   3057-MLL-NUC_3             5883 non-null   float64
#  10  3057-MRL-LP1_10            5883 non-null   float64
#  11  3057-MRL-LS1_7             5883 non-null   float64
#  12  3058-FRL_5                 5883 non-null   float64
# ...

# %%
protiens_identifiers.head(20)
# Out:
#         Sample_Name          Virus  Biotin     Fraction
# 0       1135-MRL_12        TurboID      72  whole brain
# 1    3057-MLL-LP1_2  TDP43-TurboID     1.5          LP1
# 2    3057-MLL-LS1_1  TDP43-TurboID     1.5          LS1
# 3    3057-MLL-NUC_3  TDP43-TurboID     1.5      Nuclear
# 4   3057-MRL-LP1_10  TDP43-TurboID  saline          LP1
# 5    3057-MRL-LS1_7  TDP43-TurboID  saline          LS1
# 6        3058-FRL_5        TurboID     1.5  whole brain
# 7       3058-FRU_13        TurboID      72  whole brain
# 8    3058-FRU-LP1_9        TurboID      72          LP1
# 9    3058-FRU-LS1_6        TurboID      72          LS1
# 10      3058-MRU_15  TDP43-TurboID      72  whole brain
# 11       3062-MRL_4  TDP43-TurboID     1.5  whole brain
# 12      3062-MRU_14  TDP43-TurboID      72  whole brain
# 13  3062-MRU-LP1_11  TDP43-TurboID      72          LP1
# 14   3062-MRU-LS1_8  TDP43-TurboID      72          LS1

# %%
protiens_identifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sample_Name  15 non-null     object
#  1   Virus        15 non-null     object
#  2   Biotin       15 non-null     object
#  3   Fraction     15 non-null     object
# dtypes: object(4)
# memory usage: 608.0+ bytes

# %%
protiens_identifiers["Sample_Name"] = protiens_identifiers["Sample_Name"] .astype(str)
protiens_identifiers["Virus"] = protiens_identifiers["Virus"] .astype(str)
protiens_identifiers["Biotin"] = protiens_identifiers["Biotin"] .astype(str)
protiens_identifiers["Fraction"] = protiens_identifiers["Fraction"] .astype(str)
protiens_identifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sample_Name  15 non-null     object
#  1   Virus        15 non-null     object
#  2   Biotin       15 non-null     object
#  3   Fraction     15 non-null     object
# dtypes: object(4)
# memory usage: 608.0+ bytes

# %%
protiens.to_csv("proteins_denormalized.csv")
protiens_identifiers.to_csv("proteins_identifiers_denormalized.csv")

# %%
protiens.columns
# Out:
# Index(['Protein_Names', 'Protein_Group', 'Protein_Ids', 'Genes',
#        'First_Protein_Description', 'Peptides', '1135-MRL_12',
#        '3057-MLL-LP1_2', '3057-MLL-LS1_1', '3057-MLL-NUC_3', '3057-MRL-LP1_10',
#        '3057-MRL-LS1_7', '3058-FRL_5', '3058-FRU_13', '3058-FRU-LP1_9',
#        '3058-FRU-LS1_6', '3058-MRU_15', '3062-MRL_4', '3062-MRU_14',
#        '3062-MRU-LP1_11', '3062-MRU-LS1_8'],
#       dtype='object')

# %%
protein_mouse_1 = protiens[["Protein_Names", "1135-MRL_12"]]
protein_mouse_2 = protiens[["Protein_Names", "3057-MLL-LP1_2"]]
protein_mouse_3 = protiens[["Protein_Names", "3057-MLL-LS1_1"]]
protein_mouse_4 = protiens[["Protein_Names", "3057-MLL-NUC_3"]]
protein_mouse_5 = protiens[["Protein_Names", "3057-MRL-LP1_10"]]
protein_mouse_6 = protiens[["Protein_Names", "3057-MRL-LS1_7"]]
protein_mouse_7 = protiens[["Protein_Names", "3058-FRL_5"]]
protein_mouse_8 = protiens[["Protein_Names", "3058-FRU_13"]]
protein_mouse_9 = protiens[["Protein_Names", "3058-FRU-LP1_9"]]
protein_mouse_10 = protiens[["Protein_Names", "3058-FRU-LS1_6"]]
protein_mouse_11 = protiens[["Protein_Names", "3062-MRL_4"]]
protein_mouse_12 = protiens[["Protein_Names", "3062-MRU_14"]]
protein_mouse_13 = protiens[["Protein_Names", "3062-MRU-LP1_11"]]
protein_mouse_14 = protiens[["Protein_Names", "3062-MRU-LS1_8"]]
protein_mouse_15 = protiens[["Protein_Names", "3058-MRU_15"]]


protein_mouse_1["Sample_Name"] = "1135-MRL_12"
protein_mouse_2["Sample_Name"] = "3057-MLL-LP1_2"
protein_mouse_3["Sample_Name"] = "3057-MLL-LS1_1"
protein_mouse_4["Sample_Name"] = "3057-MLL-NUC_3"
protein_mouse_5["Sample_Name"] = "3057-MRL-LP1_10"
protein_mouse_6["Sample_Name"] = "3057-MRL-LS1_7"
protein_mouse_7["Sample_Name"] = "3058-FRL_5"
protein_mouse_8["Sample_Name"] = "3058-FRU_13"
protein_mouse_9["Sample_Name"] = "3058-FRU-LP1_9"
protein_mouse_10["Sample_Name"] = "3058-FRU-LS1_6"
protein_mouse_11["Sample_Name"] = "3062-MRL_4"
protein_mouse_12["Sample_Name"] = "3062-MRU_14"
protein_mouse_13["Sample_Name"] = "3062-MRU-LP1_11"
protein_mouse_14["Sample_Name"] = "3062-MRU-LS1_8"
protein_mouse_15["Sample_Name"] = "3058-MRU_15"


protein_mouse_1 = protein_mouse_1.rename(columns = {"1135-MRL_12":"Hits"})
protein_mouse_2 = protein_mouse_2.rename(columns = {"3057-MLL-LP1_2":"Hits"})
protein_mouse_3 = protein_mouse_3.rename(columns = {"3057-MLL-LS1_1":"Hits"})
protein_mouse_4 = protein_mouse_4.rename(columns = {"3057-MLL-NUC_3":"Hits"})
protein_mouse_5 = protein_mouse_5.rename(columns = {"3057-MRL-LP1_10":"Hits"})
protein_mouse_6 = protein_mouse_6.rename(columns = {"3057-MRL-LS1_7":"Hits"})
protein_mouse_7 = protein_mouse_7.rename(columns = {"3058-FRL_5":"Hits"})
protein_mouse_8 = protein_mouse_8.rename(columns = {"3058-FRU_13":"Hits"})
protein_mouse_9 = protein_mouse_9.rename(columns = {"3058-FRU-LP1_9":"Hits"})
protein_mouse_10 = protein_mouse_10.rename(columns = {"3058-FRU-LS1_6":"Hits"})
protein_mouse_11 = protein_mouse_11.rename(columns = {"3062-MRL_4":"Hits"})
protein_mouse_12 = protein_mouse_12.rename(columns = {"3062-MRU_14":"Hits"})
protein_mouse_13 = protein_mouse_13.rename(columns = {"3062-MRU-LP1_11":"Hits"})
protein_mouse_14 = protein_mouse_14.rename(columns = {"3062-MRU-LS1_8":"Hits"})
protein_mouse_15 = protein_mouse_15.rename(columns = {"3058-MRU_15":"Hits"})
# Out:
# C:\Users\Adam Brewer\AppData\Local\Temp\ipykernel_11692\3027607657.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   protein_mouse_1["Sample_Name"] = "1135-MRL_12"
# C:\Users\Adam Brewer\AppData\Local\Temp\ipykernel_11692\3027607657.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   protein_mouse_2["Sample_Name"] = "3057-MLL-LP1_2"
# C:\Users\Adam Brewer\AppData\Local\Temp\ipykernel_11692\3027607657.py:20: SettingWithCopyWarning:
# ...

# %%
union_dfs = pd.concat([protein_mouse_1,
                       protein_mouse_2,
                       protein_mouse_3,
                       protein_mouse_4,
                       protein_mouse_5,
                       protein_mouse_6,
                       protein_mouse_7,
                       protein_mouse_8,
                       protein_mouse_9,
                       protein_mouse_10,
                       protein_mouse_11,
                       protein_mouse_12,
                       protein_mouse_13,
                       protein_mouse_14,
                       protein_mouse_15], ignore_index=True)

union_dfs = union_dfs[["Protein_Names", "Sample_Name", "Hits"]]
union_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88245 entries, 0 to 88244
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Protein_Names  88245 non-null  object
#  1   Sample_Name    88245 non-null  object
#  2   Hits           88245 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 2.0+ MB

# %%
union_dfs.to_csv("mouse_by_protein.csv")
